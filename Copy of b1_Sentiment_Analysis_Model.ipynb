# %% [markdown]
# ###Importing libraries

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Importing dataset

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd https://drive.google.com/drive/folders/1_mtA5sesNJnIlWeK8Ob6kYH_2E_yD_W5?usp=share_link
# !ls

# %%
dataset = pd.read_csv('/content/required_3.csv')

# %%
dataset.shape
# Out:
# (82, 2)

# %%
dataset.head()
# Out:
#                                               Review  Liked
# 0  The beach was stunning and the water was cryst...      1
# 1   The hotel room was dirty and smelled like smoke.      0
# 2  The historical tour was very informative and o...      1
# 3  The food at the restaurant was terrible and ov...      0
# 4  The theme park had a lot of exciting rides and...      1

# %% [markdown]
# ### Data Preprocessing

# %%
import re
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
corpus=[]

for i in range(0, 82):
  review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i])
  review = review.lower()
  review = review.split()
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)

# %%
corpus
# Out:
# ['beach stun water crystal clear',
#  'hotel room dirti smell like smoke',
#  'histor tour inform guid excel',
#  'food restaur terribl overpr',
#  'theme park lot excit ride attract',
#  'servic hotel slow unrespons',
#  'view mountain top breathtak',
#  'citi tour disorgan see half promis',
#  'museum great collect interact exhibit',
#  'accommod uncomfort outdat',
#  'safari experi unforgett guid knowledg',
#  'custom servic amus park terribl unhelp',
#  'local market great select fresh produc uniqu souvenir',
#  'hike trail poorli mark difficult follow',
#  'concert amaz sound qualiti top notch',
#  'public transport confus unreli',
#  'aquarium well maintain varieti sea life',
#  'hotel staff rude unprofession',
#  'zoo great varieti anim educ exhibit',
#  'beach overcrowd noisi',
#  'walk tour great way see citi learn histori',
#  'amus park expens not worth money',
#  'art museum stun collect paint sculptur',
#  'rental car mechan problem hassl deal',
#  'water park fun excit way cool hot day',
#  'hotel bed bug infest move room',
#  'boat tour relax enjoy way see coastlin',
#  'restaur terribl servic food cold',
#  'botan garden beauti well maintain',
#  'hotel great locat room noisi uncomfort',
#  'theme park great select ride age',
#  'airport shuttl late caus us miss flight',
#  'scienc museum interact exhibit fun educ',
#  'hotel pool dirti uninvit',
#  'music festiv great lineup well organ',
#  'tour bu cramp uncomfort',
#  'nation park stun natur beauti hike trail',
#  'hotel mold problem switch room',
#  'sport stadium great seat live atmospher',
#  'public restroom dirti poorli maintain',
#  'theme park lot food option qualiti poor',
#  'sceneri absolut breathtak could spend hour take view',
#  'local friendli welcom realli made stay unforgett',
#  'food incred tri mani delici dish never even heard',
#  'histor landmark architectur stun felt like transport back time',
#  'beach beauti ever seen crystal clear water soft sand',
#  'nightlif vibrant live alway someth fun even',
#  'hike trail well maintain offer stun view surround natur',
#  'cultur event festiv uniqu interest love experienc local tradit',
#  'shop fantast mani local artisan uniqu boutiqu',
#  'public transport conveni easi use troubl get around',
#  'museum galleri world class fascin exhibit collect',
#  'weather perfect sunni warm everi day',
#  'park garden peac well maintain great place relax unwind',
#  'adventur activ like raft zip line much fun great way get adrenalin pump',
#  'accommod luxuri comfort felt pamper throughout stay',
#  'local market amaz fresh produc love tri differ fruit veget',
#  'histor site well preserv inform learn much local cultur histori',
#  'weather terribl rain everi day',
#  'local rude unfriendli make stay unpleas',
#  'histor landmark poorli maintain not worth visit',
#  'beach dirti crowd not relax experi hope',
#  'hike trail poorli mark difficult navig',
#  'museum galleri underwhelm lacklust exhibit collect',
#  'park garden unkempt not enjoy visit',
#  'accommod run not expect',
#  'local wine beer disappoint not worth cost',
#  'beach touristi not enjoy visit',
#  'nightlif loud rowdi us enjoy',
#  'public transport expens poor servic provid',
#  'accommod run not expect',
#  'architectur design build unimpress lacklust',
#  'local tour guid unhelp uninterest job',
#  'local art music scene lack divers creativ',
#  'nightlif divers option everi tast prefer',
#  'art music scene thrive mani talent artist musician',
#  'local market amaz fresh produc love tri differ fruit veget',
#  'cultur event festiv uniqu interest love experienc local tradit',
#  'public transport eco friendli effici great way explor reduc carbon footprint',
#  'local art music scene lack divers creativ',
#  'food option limit not suitabl dietari need',
#  'public transport slow caus us miss activ']

# %% [markdown]
# ### Data transformation

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1420)

# %%
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, -1].values

# %%
# Saving BoW dictionary to later use in prediction
import pickle
bow_path = 'c1_BoW_Sentiment_Model.pkl'
pickle.dump(cv, open(bow_path, "wb"))

# %% [markdown]
# ### Dividing dataset into training and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ### Model fitting (Naive Bayes)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Exporting NB Classifier to later use in prediction
import joblib
joblib.dump(classifier, 'c2_Classifier_Sentiment_Model')
# Out:
# ['c2_Classifier_Sentiment_Model']

# %% [markdown]
# ###Model performance

# %%
y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy_score(y_test, y_pred)
# Out:
# [[5 2]
#  [2 8]]
# 0.7647058823529411
